# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.uniform(-2, 2, 10000)

def f(x):
  return 1 + x**2

eps = np.random.normal(size=x.size) * x

# %%
y = f(x) + eps

# %%
# plt.scatter(x, f(x), s=1)
plt.scatter(x, y, s=1)

# %%
ones = np.ones_like(x)
X = np.column_stack([ones, x, x**2])
Θ = np.linalg.lstsq(X, y)[0]
# Out:
# <ipython-input-52-b2bf7b7140d0>:3: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   Θ = np.linalg.lstsq(X, y)[0]

# %%
predicted = X @ Θ

plt.figure(figsize=[10, 5])
plt.scatter(x, f(x), s=3)
#plt.scatter(x, y, s=1)
plt.scatter(x, predicted, s=.1, color='r')

# %%
X1 = np.column_stack([x**k for k in range(3)])
Θ1 = np.linalg.lstsq(X1, y)[0]
predicted1 = X1 @ Θ1
# Out:
# <ipython-input-39-692546ae4358>:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   Θ1 = np.linalg.lstsq(X1, y)[0]

# %%
plt.figure(figsize=[10, 5])
plt.scatter(x, f(x), s=3)
#plt.scatter(x, y, s=1)
plt.scatter(x, predicted1, s=.1, color='r')
